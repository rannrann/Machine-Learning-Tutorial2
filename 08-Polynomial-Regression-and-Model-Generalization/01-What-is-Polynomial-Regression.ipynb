# %% [markdown]
# ## 什么是多项式回归

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-3, 3, size = 100)
X = x.reshape(-1, 1)
y = 0.5 * x ** 2 + x + 2 + np.random.normal(0, 1, 100)

# %%
plt.scatter(x, y)

# %% [markdown]
# ## 线性回归

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_predict = lin_reg.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict, color = 'r')

# %% [markdown]
# ## 解决方案，添加一个特征

# %%
X2 = np.hstack([X, X**2])
lin_reg2 = LinearRegression()
lin_reg2.fit(X2, y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict2, color = "r") #这是绘制折线图的函数，所以要想绘制平滑的曲线，要从小到大排列。散点图就不会涉及这个问题

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], color = "r")

# %%
lin_reg2.coef_
# Out:
# array([0.99374503, 0.52278682])

# %%
lin_reg2.intercept_
# Out:
# 1.8318746238432078
